# %% [markdown]
# ##Load Pre-Trained Model -ResNet50

# %%
from tensorflow.keras.applications.resnet50 import ResNet50,preprocess_input,decode_predictions
from tensorflow.keras.applications import vgg16
from tensorflow.keras.preprocessing import image
import glob
import numpy as np
import pandas as pd
import cv2
from google.colab.patches import cv2_imshow

# %% [markdown]
# Test ResNet50 Model on sample Images

# %%
#Load ResNet50 model
resnet_model=ResNet50(weights='imagenet')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels.h5
# 102973440/102967424 [==============================] - 1s 0us/step
# 102981632/102967424 [==============================] - 1s 0us/step

# %%
#Load path of data
path=glob.glob('/content/drive/MyDrive/Colab Notebooks/hateful_memes/image_no_caption/*.jpg')
path
# Out:
# ['/content/drive/MyDrive/Colab Notebooks/hateful_memes/image_no_caption/img_1.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/hateful_memes/image_no_caption/img_2.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/hateful_memes/image_no_caption/img_3.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/hateful_memes/image_no_caption/img_4.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/hateful_memes/image_no_caption/img_5.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/hateful_memes/image_no_caption/img_6.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/hateful_memes/image_no_caption/img_7.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/hateful_memes/image_no_caption/img_8.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/hateful_memes/image_no_caption/img_9.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/hateful_memes/image_no_caption/img_10.jpg']

# %%
for file in path:
  #from tensorflow.keras.preprocessing import image 
  img_file=cv2.imread(file)
  img_file=cv2.resize(img_file,(224,224))
  cv2_imshow(img_file)
  x_file=image.img_to_array(img_file)
  #print(type(x_file))
  y_file=np.expand_dims(x_file,axis=0)
  #print(type(y_file))
  z_file=preprocess_input(y_file)
  #print(type(z_file))
  preds_file=resnet_model.predict(z_file)
  #print(type(preds_file))
  #print(preds_file)
  Prediction_file=decode_predictions(preds_file, top=3)[0]
  #print(type(Prediction_file))
  print('Predicted:', Prediction_file)
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F4D4C1ADD50>
# Predicted: [('n02088094', 'Afghan_hound', 0.18553688), ('n02093647', 'Bedlington_terrier', 0.18266231), ('n02091635', 'otterhound', 0.16204667)]
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F4D4C1F5A50>
# Predicted: [('n02123045', 'tabby', 0.3190108), ('n03980874', 'poncho', 0.11460898), ('n02843684', 'birdhouse', 0.088050745)]
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F4D4C0E90D0>
# Predicted: [('n02127052', 'lynx', 0.28680584), ('n02123159', 'tiger_cat', 0.17366447), ('n02124075', 'Egyptian_cat', 0.15608032)]
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F4D4C0E9150>
# Predicted: [('n02091831', 'Saluki', 0.6970942), ('n02090622', 'borzoi', 0.14856324), ('n03903868', 'pedestal', 0.07604726)]
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F4D4C0A0410>
# Predicted: [('n02504458', 'African_elephant', 0.9338404), ('n01871265', 'tusker', 0.04660994), ('n02504013', 'Indian_elephant', 0.0028264436)]
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F4D4C037990>
# Predicted: [('n02129165', 'lion', 0.71450716), ('n02105056', 'groenendael', 0.10380666), ('n02106030', 'collie', 0.056855)]
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F4D4C232950>
# Predicted: [('n02391049', 'zebra', 0.9990165), ('n02422106', 'hartebeest', 0.00060896593), ('n02422699', 'impala', 0.0001844052)]
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F4D4C17A910>
# Predicted: [('n03623198', 'knee_pad', 0.3907448), ('n04228054', 'ski', 0.12210833), ('n03255030', 'dumbbell', 0.1019839)]
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F4D4C0AD090>
# Predicted: [('n04317175', 'stethoscope', 0.36836645), ('n04209239', 'shower_curtain', 0.07992715), ('n03630383', 'lab_coat', 0.0736756)]
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F4D4C073CD0>
# Predicted: [('n02326432', 'hare', 0.5167141), ('n02325366', 'wood_rabbit', 0.48276177), ('n02328150', 'Angora', 0.00029955397)]

# %% [markdown]
# #Using VGG16 Model

# %%
#Load vgg model
vgg_model= vgg16.VGG16(weights='imagenet')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels.h5
# 553467904/553467096 [==============================] - 3s 0us/step
# 553476096/553467096 [==============================] - 3s 0us/step

# %%
for file in path:
  #from tensorflow.keras.preprocessing import image 
  img_file=cv2.imread(file)
  img_file=cv2.resize(img_file,(224,224))
  cv2_imshow(img_file)
  x_file=image.img_to_array(img_file)
  #print(type(x_file))
  y_file=np.expand_dims(x_file,axis=0)
  #print(type(y_file))
  z_file=preprocess_input(y_file)
  #print(type(z_file))
  preds_file=vgg_model.predict(z_file)
  #print(type(preds_file))
  #print(preds_file)
  Prediction_file=decode_predictions(preds_file, top=3)[0]
  #print(type(Prediction_file))
  print('Predicted:', Prediction_file)
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F4D4C180890>
# Predicted: [('n02104029', 'kuvasz', 0.5675227), ('n02093647', 'Bedlington_terrier', 0.13967489), ('n02111500', 'Great_Pyrenees', 0.11470829)]
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F4D4C13F550>
# Predicted: [('n04532106', 'vestment', 0.19559179), ('n04522168', 'vase', 0.19186889), ('n04209133', 'shower_cap', 0.103469476)]
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F4DD000AFD0>
# Predicted: [('n02124075', 'Egyptian_cat', 0.30361035), ('n02123045', 'tabby', 0.263522), ('n02123159', 'tiger_cat', 0.1632201)]
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F4D4C1AA7D0>
# Predicted: [('n02091831', 'Saluki', 0.32031465), ('n01632777', 'axolotl', 0.16436984), ('n02090622', 'borzoi', 0.114140935)]
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F4D4C21BA10>
# Predicted: [('n01871265', 'tusker', 0.5578284), ('n02504458', 'African_elephant', 0.41058248), ('n02504013', 'Indian_elephant', 0.031574845)]
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F4D4C11A290>
# Predicted: [('n02129165', 'lion', 0.9263714), ('n02129604', 'tiger', 0.019646624), ('n02114367', 'timber_wolf', 0.013707473)]
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F4D4C0BDE10>
# Predicted: [('n02391049', 'zebra', 0.9997806), ('n02423022', 'gazelle', 0.00013719963), ('n02422699', 'impala', 6.765549e-05)]
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F4D4C0AD210>
# Predicted: [('n06359193', 'web_site', 0.32680708), ('n04371430', 'swimming_trunks', 0.052747134), ('n04404412', 'television', 0.035997182)]
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F4D4C1AAC90>
# Predicted: [('n04317175', 'stethoscope', 0.23555772), ('n03630383', 'lab_coat', 0.1446378), ('n03584829', 'iron', 0.037795614)]
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F4D4C239ED0>
# Predicted: [('n02325366', 'wood_rabbit', 0.8462519), ('n02326432', 'hare', 0.1537475), ('n02328150', 'Angora', 3.187849e-07)]
